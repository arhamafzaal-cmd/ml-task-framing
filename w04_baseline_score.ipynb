# %%
import shutil, os, glob
shutil.rmtree(os.path.expanduser("~/.cache/huggingface/datasets/FlyRank___internship-warehouse"), ignore_errors=True)
print("Cache cleared!")
# Out:
# Cache cleared!

# %%
import os
import json
import duckdb
import pandas as pd
from datasets import load_dataset

os.makedirs("../outputs", exist_ok=True)

# Replace the string below with your actual token (e.g., "hf_abc12345...")
MY_HF_TOKEN = os.environ.get("HF_TOKEN", "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")

dataset_dict = load_dataset(
    "FlyRank/internship-warehouse",
    data_dir="fact_content_daily_performance/month=2025-03",
    token=MY_HF_TOKEN
)

df_raw = dataset_dict["train"].to_pandas()
con = duckdb.connect()
con.register("raw_table", df_raw)
print(f"Successfully loaded dataset: {len(df_raw)} rows.")
# Out:
# ---------------------------------------------------------------------------
# DatasetNotFoundError                      Traceback (most recent call last)
# Cell In[6], line 12
#       8 os.makedirs("../outputs", exist_ok=True)
#       9
#      10 MY_HF_TOKEN = os.environ.get("HF_TOKEN", "YOUR_HF_TOKEN_HERE")
#      11
# ---> 12 dataset_dict = load_dataset(
#      13     "FlyRank/internship-warehouse",
#      14     data_dir="fact_content_daily_performance/month=2025-03",
#      15     token=MY_HF_TOKEN,
#
# File c:\Users\AL-SULTAN TECH\AppData\Local\Programs\Python\Python312\Lib\site-packages\datasets\load.py:1696, in load_dataset(path, name, data_dir, data_files, split, cache_dir, features, download_config, download_mode, verification_mode, keep_in_memory, save_infos, revision, token, streaming, num_proc, storage_options, **config_kwargs)
#    1691 verification_mode = VerificationMode(
# ...
